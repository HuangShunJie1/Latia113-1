# %%
import numpy as np
import pandas as pd
s=pd.Series([1,3,5,np.nan,6,8])
print(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
#                    A         B         C         D
# 2013-01-01 -1.744270  0.556867  1.764178  0.583489
# 2013-01-02 -0.538522 -1.196638 -0.433776 -1.418278
# 2013-01-03  1.341733  0.530257 -0.895544  0.015582
# 2013-01-04  2.497166  0.743205  0.209643  1.373836
# 2013-01-05 -0.765203 -0.749264  0.510157  1.400033
# 2013-01-06 -0.201721 -0.034654  0.363684  0.476991

# %%
dates=pd.date_range("20130101",periods=6)
dates=['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
               '2013-01-05', '2013-01-06']

# %%
df=pd.DataFrame(np.random.randn(6,4),index=dates,columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.848729  2.868258  0.740121  1.211523
# 2013-01-02  1.885711 -2.487977  0.236313 -1.546053
# 2013-01-03  0.334124  0.030677 -1.035529  1.182680
# 2013-01-04 -1.128017 -2.312010 -1.364440 -1.577680
# 2013-01-05 -0.511554  0.317908  0.823730 -1.061015
# 2013-01-06 -1.556137 -0.052016  1.066231 -1.545539

# %%
print(df.head())
print(df.tail(3))
print(df.index)
print(df.columns)
# Out:
#                    A         B         C         D
# 2013-01-01  0.848729  2.868258  0.740121  1.211523
# 2013-01-02  1.885711 -2.487977  0.236313 -1.546053
# 2013-01-03  0.334124  0.030677 -1.035529  1.182680
# 2013-01-04 -1.128017 -2.312010 -1.364440 -1.577680
# 2013-01-05 -0.511554  0.317908  0.823730 -1.061015
#                    A         B         C         D
# 2013-01-04 -1.128017 -2.312010 -1.364440 -1.577680
# 2013-01-05 -0.511554  0.317908  0.823730 -1.061015
# 2013-01-06 -1.556137 -0.052016  1.066231 -1.545539
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df2=df.copy()
print(df2)
print(df2.to_numpy())
# Out:
#                    A         B         C         D
# 2013-01-01  0.848729  2.868258  0.740121  1.211523
# 2013-01-02  1.885711 -2.487977  0.236313 -1.546053
# 2013-01-03  0.334124  0.030677 -1.035529  1.182680
# 2013-01-04 -1.128017 -2.312010 -1.364440 -1.577680
# 2013-01-05 -0.511554  0.317908  0.823730 -1.061015
# 2013-01-06 -1.556137 -0.052016  1.066231 -1.545539
# [[ 0.84872905  2.86825812  0.74012054  1.21152331]
#  [ 1.88571109 -2.48797685  0.23631292 -1.54605263]
#  [ 0.33412419  0.03067704 -1.03552864  1.18267975]
#  [-1.12801685 -2.31200972 -1.36443967 -1.5776799 ]
#  [-0.5115537   0.31790825  0.82372974 -1.06101541]
#  [-1.55613658 -0.05201555  1.06623139 -1.54553949]]

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.021190 -0.272526  0.077738 -0.556014
# std    1.291578  1.970858  1.031189  1.371525
# min   -1.556137 -2.487977 -1.364440 -1.577680
# 25%   -0.973901 -1.747011 -0.717568 -1.545924
# 50%   -0.088715 -0.010669  0.488217 -1.303277
# 75%    0.720078  0.246100  0.802827  0.621756
# max    1.885711  2.868258  1.066231  1.211523

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  1.211523  0.740121  2.868258  0.848729
# 2013-01-02 -1.546053  0.236313 -2.487977  1.885711
# 2013-01-03  1.182680 -1.035529  0.030677  0.334124
# 2013-01-04 -1.577680 -1.364440 -2.312010 -1.128017
# 2013-01-05 -1.061015  0.823730  0.317908 -0.511554
# 2013-01-06 -1.545539  1.066231 -0.052016 -1.556137

# %%
print(df["A"])
print(df[0:3])
print(df["A"][0:3])
# Out:
# 2013-01-01    0.848729
# 2013-01-02    1.885711
# 2013-01-03    0.334124
# 2013-01-04   -1.128017
# 2013-01-05   -0.511554
# 2013-01-06   -1.556137
# Freq: D, Name: A, dtype: float64
#                    A         B         C         D
# 2013-01-01  0.848729  2.868258  0.740121  1.211523
# 2013-01-02  1.885711 -2.487977  0.236313 -1.546053
# 2013-01-03  0.334124  0.030677 -1.035529  1.182680
# 2013-01-01    0.848729
# 2013-01-02    1.885711
# 2013-01-03    0.334124
# Freq: D, Name: A, dtype: float64

# %%
print(df)
print(df.loc[dates[0]])
print(df.loc[:,["A","B"]])
print(df[["A","B"]])
print(df.loc["20130102":"20130104",["A","B"]])
print(df.loc[dates[0],"A"])
print(df.iloc[3])
print(df[df["A"]>0][["A","C"]])
print(df.loc[df["A"]>0,["A","C"]])
# Out:
#                    A         B         C         D
# 2013-01-01  0.848729  2.868258  0.740121  1.211523
# 2013-01-02  1.885711 -2.487977  0.236313 -1.546053
# 2013-01-03  0.334124  0.030677 -1.035529  1.182680
# 2013-01-04 -1.128017 -2.312010 -1.364440 -1.577680
# 2013-01-05 -0.511554  0.317908  0.823730 -1.061015
# 2013-01-06 -1.556137 -0.052016  1.066231 -1.545539
# A    0.848729
# B    2.868258
# C    0.740121
# D    1.211523
# Name: 2013-01-01 00:00:00, dtype: float64
#                    A         B
# 2013-01-01  0.848729  2.868258
# 2013-01-02  1.885711 -2.487977
# 2013-01-03  0.334124  0.030677
# 2013-01-04 -1.128017 -2.312010
# 2013-01-05 -0.511554  0.317908
# 2013-01-06 -1.556137 -0.052016
#                    A         B
# 2013-01-01  0.848729  2.868258
# 2013-01-02  1.885711 -2.487977
# 2013-01-03  0.334124  0.030677
# 2013-01-04 -1.128017 -2.312010
# 2013-01-05 -0.511554  0.317908
# 2013-01-06 -1.556137 -0.052016
#                    A         B
# 2013-01-02  1.885711 -2.487977
# 2013-01-03  0.334124  0.030677
# 2013-01-04 -1.128017 -2.312010
# 0.8487290545033112
# A   -1.128017
# B   -2.312010
# C   -1.364440
# D   -1.577680
# Name: 2013-01-04 00:00:00, dtype: float64
#                    A         C
# 2013-01-01  0.848729  0.740121
# 2013-01-02  1.885711  0.236313
# 2013-01-03  0.334124 -1.035529
#                    A         C
# 2013-01-01  0.848729  0.740121
# 2013-01-02  1.885711  0.236313
# 2013-01-03  0.334124 -1.035529
